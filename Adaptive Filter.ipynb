# %% [markdown]
# # **Adaptive Filter**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img1 = "image_path"
original_image = cv2.imread(img1)

if original_image is None:
    print("Error: Image not found")
else:
    filtered_img1 = cv2.bilateralFilter(original_image, d=9, sigmaColor=75, sigmaSpace=75)

    psnr_value = cv2.PSNR(original_image, filtered_img1)
    print(f"PSNR between original and filtered image: {psnr_value} dB")

    def display_images(original, processed, title1="Original", title2="Processed"):
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 2, 1)
        if len(original.shape) == 2:
            plt.imshow(original, cmap="gray")
        else:
            plt.imshow(cv2.cvtColor(original, cv2.COLOR_BGR2RGB))
        plt.title(title1)
        plt.axis("off")

        plt.subplot(1, 2, 2)
        if len(processed.shape) == 2:
            plt.imshow(processed, cmap="gray")
        else:
            plt.imshow(cv2.cvtColor(processed, cv2.COLOR_BGR2RGB))
        plt.title(title2)
        plt.axis("off")
        plt.show()

    display_images(original_image, filtered_img1, "Original", "Adaptive Filter")
# Out:
# PSNR between original and filtered image: 25.283319876262134 dB
